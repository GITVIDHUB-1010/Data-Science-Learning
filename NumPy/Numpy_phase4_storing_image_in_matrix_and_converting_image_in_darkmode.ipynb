# %% [markdown]
# #Storing the arrays

# %%
import numpy as np
import matplotlib as plt

# %%
arr1= np.array([[1,2,3,9],[4,5,6,7]])
arr2 =np.ones([3,3])
arr3 = np.array([2,4,6,8])

# %%
np.save("array 1.npy",arr1)
np.save("array 2.npy",arr2)
np.save("array 3.npy",arr3)

# %%
loaded = np.load("array 1.npy")
print(loaded)
# Out:
# [[1 2 3 9]
#  [4 5 6 7]]
