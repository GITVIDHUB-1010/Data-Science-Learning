# %% [markdown]
# #Pandas Series

# %%
import numpy as np
import pandas as pd

# %%
labels = ["a","b","c"]
lists = [10,20,30,40,50,60]
arr = np.array([10,20,30])
di = {1:20,2:30,3:40}

# %%
pd.Series(di)
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pd.Series(arr,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
