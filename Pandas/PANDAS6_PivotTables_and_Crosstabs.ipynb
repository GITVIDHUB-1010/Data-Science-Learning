# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice',
            'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice',
            'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A  North    699     72   John  January      Q1
# 1  2023-01-02       B  South    441     83   Mary  January      Q1
# 2  2023-01-03       C   East    414     96    Bob  January      Q1
# 3  2023-01-04       D   West    174     49  Alice  January      Q1
# 4  2023-01-05       A  North    307     68   John  January      Q1
# 5  2023-01-06       B  South    165     97   Mary  January      Q1
# 6  2023-01-07       C   East    206     99    Bob  January      Q1
# 7  2023-01-08       D   West    585     32  Alice  January      Q1
# 8  2023-01-09       A  North    380     57   John  January      Q1
# 9  2023-01-10       B  South    902     12   Mary  January      Q1
# 10 2023-01-11       C   East    194     79    Bob  January      Q1
# 11 2023-01-12       D   West    934     78  Alice  January      Q1
# 12 2023-01-13       A  North    611     98   John  January      Q1
# 13 2023-01-14       B  South    558     53   Mary  January      Q1
# 14 2023-01-15       C   East    296     79    Bob  January      Q1
# 15 2023-01-16       D   West    925     31  Alice  January      Q1
# 16 2023-01-17       A  North    526     53   John  January      Q1
# 17 2023-01-18       B  South    992     37   Mary  January      Q1
# 18 2023-01-19       C   East    334     12    Bob  January      Q1
# 19 2023-01-20       D   West    220     90  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product",aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East       NaN    NaN  296.0    NaN
# North    526.0    NaN    NaN    NaN
# South      NaN  558.0    NaN    NaN
# West       NaN    NaN    NaN  585.0

# %%
pivot2= pd.pivot_table(df, values =["Sales","Units"],index="Region",columns="Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East       NaN    NaN  288.8    NaN   NaN   NaN  73.0   NaN
# North    504.6    NaN    NaN    NaN  69.6   NaN   NaN   NaN
# South      NaN  611.6    NaN    NaN   NaN  56.4   NaN   NaN
# West       NaN    NaN    NaN  567.6   NaN   NaN   NaN  56.0

# %%
pivot2.fillna(value=0)
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East       0.0    0.0  288.8    0.0   0.0   0.0  73.0   0.0
# North    504.6    0.0    0.0    0.0  69.6   0.0   0.0   0.0
# South      0.0  611.6    0.0    0.0   0.0  56.4   0.0   0.0
# West       0.0    0.0    0.0  567.6   0.0   0.0   0.0  56.0

# %%
pd.crosstab(df["Region"],df["Product"]) #A crosstabulation (crosstab) is used to count how often combinations of categories occur.
# Out:
# Product  A  B  C  D
# Region
# East     0  0  5  0
# North    5  0  0  0
# South    0  5  0  0
# West     0  0  0  5
